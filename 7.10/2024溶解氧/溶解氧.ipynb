# %%
import numpy as np    
import pandas as pd    
import matplotlib.pyplot as plt  
import os  
import cartopy.crs as ccrs  
import cartopy.feature as cfeature  
import matplotlib.ticker as mticker  
from matplotlib.ticker import MultipleLocator, FuncFormatter
import matplotlib.colors as mcolors  
# import gsw

# %%
wen_jian_jia = os.listdir(r'D:\最新数据\分海区')
print(wen_jian_jia)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 wen_jian_jia = os.listdir(r'D:\最新数据\分海区')
#       2 print(wen_jian_jia)
#
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: 'D:\\最新数据\\分海区'

# %%
def dms_to_decimal(dms):
    """将度分秒转换为十进制度数"""
    dms = dms.replace('°', ' ').replace('′', ' ').replace('″', ' ').replace('"E', ' ').replace('"N', ' ').replace('"S', ' ')
    parts = dms.split()
    degrees = float(parts[0])
    minutes = float(parts[1]) if len(parts) > 1 else 0
    seconds = float(parts[2]) if len(parts) > 2 else 0
    decimal = degrees + (minutes / 60) + (seconds / 3600)
    return decimal

# %%
def draw(path_name, num):
    all_salinities = []
    all_depths = []
    all_o2 = []  
    all_temperatures = []
    colors = ['blue', 'green', 'orange', 'purple', 'red']

    fig = plt.figure(figsize=(10, 8))
    ax1 = fig.add_subplot(111)

    hai_qu_wenjianjia = os.listdir(rf'D:\最新数据\分海区\{path_name}')
    for i in hai_qu_wenjianjia :
        if i.endswith('.xls'):
            df = pd.read_excel(os.path.join(rf'D:\最新数据\分海区\{path_name}', i), skiprows=3, usecols=[1,5,6,8,11,13,16], names=['站位名', '纬度', '经度', '深度', '水温', '盐度', '溶解氧'])
            depth = df['深度']
            salinity = df['盐度']
            o2 = df['溶解氧']
            t = df['水温']
            all_depths.append(depth)
            all_temperatures.append(t)
            all_salinities.append(salinity)
            all_o2.append(o2)
            ax1.scatter(depth, o2, s=10, marker='o', c=colors[num], alpha=0.5)
    # # 合并所有文件的数据
    # depth = pd.concat(all_depths, ignore_index=True)
    # t = pd.concat(all_temperatures, ignore_index=True)
    # salinity = pd.concat(all_salinities, ignore_index=True)
    # o2 = pd.concat(all_o2, ignore_index=True)
    # ax1.scatter(depth, o2, s=10, marker='o', c=colors[idx], alpha=0.5)
    plt.show()

# %%
def draw(path_names):
    all_salinities = []
    all_depths = []
    all_o2 = []  
    all_temperatures = []
    plt.rcParams['font.size'] = 14
    # 获取所有可能的颜色
    all_colors = ['#8B8970', '#FFA54F', '#3CB371', '#8B2500', '#E066FF']
    all_markers = ['o', 'D', 'X', '*', '^']
    # 确保颜色数量足够
    colors = all_colors[:len(path_names)]
    
    fig = plt.figure(figsize=(10, 8))
    ax1 = fig.add_subplot(111)
    
    for idx, path_name in enumerate(path_names):
        hai_qu_wenjianjia = os.listdir(rf'D:\最新数据\分海区\{path_name}')
        first_file = True  # 用于标记是否是第一个文件
        for i in hai_qu_wenjianjia:
            if i.endswith('.xls'):
                df = pd.read_excel(os.path.join(rf'D:\最新数据\分海区\{path_name}', i), skiprows=3, usecols=[1,5,6,8,11,13,16], names=['站位名', '纬度', '经度', '深度', '水温', '盐度', '溶解氧'])
                depth = df['深度']
                o2 = df['溶解氧']
                if first_file:
                    ax1.scatter(o2, depth, s=5, marker=all_markers[idx], c=colors[idx], alpha=0.5, label=path_name)
                    first_file = False
                else:
                    ax1.scatter(o2, depth, s=5, marker=all_markers[idx], c=colors[idx], alpha=0.5)
        ax1.set_ylim(3000, 6000)
        ax1.set_xlim(100, 145)
        ax1.set_xlabel('O2 (μmol/kg)')
        ax1.set_ylabel('Depth (m)')
        ax1.spines[:].set_linewidth(2)
        ax1.invert_yaxis()
    
    plt.legend(markerscale=2)
    plt.savefig('depth_o2.png', bbox_inches='tight', dpi=300)

# 调用函数
draw(wen_jian_jia)

# %%
def draw(path_names):
    all_salinities = []
    all_depths = []
    all_o2 = []  
    all_temperatures = []
    plt.rcParams['font.size'] = 14
    # 获取所有可能的颜色
    all_colors = ['#8B8970', '#FFA54F', '#3CB371', '#8B2500', '#E066FF']
    all_markers = ['o', 'D', 'X', '*', '^']
    # 确保颜色数量足够
    colors = all_colors[:len(path_names)]
    
    fig = plt.figure(figsize=(10, 10))
    ax1 = fig.add_subplot(111)
    
    for idx, path_name in enumerate(path_names):
        hai_qu_wenjianjia = os.listdir(rf'D:\最新数据\分海区\{path_name}')
        first_file = True  # 用于标记是否是第一个文件
        for i in hai_qu_wenjianjia:
            if i.endswith('.xls'):
                df = pd.read_excel(os.path.join(rf'D:\最新数据\分海区\{path_name}', i), skiprows=3, usecols=[1,5,6,8,10,11,13,16], names=['站位名', '纬度', '经度', '深度', '压力', '水温', '盐度', '溶解氧'])
                df_1 = df[df['深度'] >= 2000]
                depth = df['深度']
                depth_1 = df_1['深度'].values.astype(float)
                o2 = df['溶解氧']
                salinity = df['盐度']
                salinity_1 = df_1['盐度'].values.astype(float)
                t = df['水温']
                t_1 = df_1['水温'].values.astype(float)
                print(t_1)
                p = df['压力'] * 0.01 - 10.1325
                p_1 = df_1['压力'].values * 0.01 -10.1325
                lon = df['经度'].apply(dms_to_decimal)
                lon_1 = df_1['经度'].apply(dms_to_decimal).values.astype(float)
                lat = df['纬度'].apply(dms_to_decimal)
                lat_1 = df_1['纬度'].apply(dms_to_decimal).values.astype(float)
                ab_salinity = gsw.SA_from_SP(salinity_1, p_1, lon_1, lat_1)
                print(ab_salinity)
                pt = gsw.pt0_from_t(ab_salinity, t_1, p_1)
                print(pt)
                if first_file:
                    ax1.scatter(salinity_1, t_1, s=8, marker=all_markers[idx], c=colors[idx], alpha=0.5, label=path_name)
                    first_file = False
                else:
                    ax1.scatter(salinity_1, t_1, s=8, marker=all_markers[idx], c=colors[idx], alpha=0.5)
        # ax1.set_xlim(34.61, 34.73)
        # ax1.set_ylim(1, 2.5)
        ax1.set_xlabel('salinity')
        ax1.set_ylabel('Potential Temperature (°C)')
        ax1.spines[:].set_linewidth(2)
        # ax1.invert_yaxis()
        # 绘制位势密度等值线
    salinity_range = np.linspace(34.6, 34.7, 10)
    temperature_range = np.linspace(1, 2.5, 10)
    salinity_grid, temperature_grid = np.meshgrid(salinity_range, temperature_range)
    density_grid = gsw.sigma0(salinity_grid, temperature_grid)

    cs = ax1.contour(salinity_grid, temperature_grid, density_grid, levels=np.arange(27.5, 27.7, 0.01), colors='gray', linewidths=0.5, linestyles='dashed')
    ax1.clabel(cs, fmt='%2.2f', colors='black', fontsize=8)
    
    plt.legend(markerscale=2)
    plt.savefig('salinity_pt_2000_nocal.png', bbox_inches='tight', dpi=300)

# 调用函数
draw(wen_jian_jia)

# %%
def draw(path_names):
    plt.rcParams['font.size'] = 14
    all_colors = ['#8B8970', '#FFA54F', '#3CB371', '#8B2500', '#E066FF']
    all_markers = ['o', 'D', 'X', '*', '^']
    colors = all_colors[:len(path_names)]
    
    fig = plt.figure(figsize=(10, 10))
    ax1 = fig.add_subplot(111)
    
    for idx, path_name in enumerate(path_names):
        hai_qu_wenjianjia = os.listdir(rf'D:\最新数据\分海区\{path_name}')
        first_file = True
        for i in hai_qu_wenjianjia:
            if i.endswith('.xls'):
                df = pd.read_excel(os.path.join(rf'D:\最新数据\分海区\{path_name}', i), skiprows=3, usecols=[1,5,6,8,10,11,13,16], names=['站位名', '纬度', '经度', '深度', '压力', '水温', '盐度', '溶解氧'])
                df_1 = df[df['深度'] >= 2000]
                depth = df['深度']
                depth_1 = df_1['深度'].values.astype(float)
                o2 = df['溶解氧']
                salinity = df['盐度']
                salinity_1 = df_1['盐度'].values.astype(float)
                t = df['水温']
                t_1 = df_1['水温'].values.astype(float)
                print("Original Temperatures:", t_1)
                p = df['压力'] * 0.1 - 10.1325
                p_1 = df_1['压力'].values * 0.1 - 10.1325
                lon = df['经度'].apply(dms_to_decimal)
                lon_1 = df_1['经度'].apply(dms_to_decimal).values.astype(float)
                lat = df['纬度'].apply(dms_to_decimal)
                lat_1 = df_1['纬度'].apply(dms_to_decimal).values.astype(float)
                
                ab_salinity = gsw.SA_from_SP(salinity_1, p_1, lon_1, lat_1)
                print("Absolute Salinities:", ab_salinity)
                pt = gsw.pt0_from_t(ab_salinity, t_1, p_1)
                print("Potential Temperatures:", pt)
                
                if first_file:
                    ax1.scatter(salinity_1, pt, s=8, marker=all_markers[idx], c=colors[idx], alpha=0.5, label=path_name)
                    first_file = False
                else:
                    ax1.scatter(salinity_1, pt, s=8, marker=all_markers[idx], c=colors[idx], alpha=0.5)
        
    ax1.set_ylim(1, 2.5)
    ax1.set_xlabel('salinity')
    ax1.set_ylabel('Potential Temperature (°C)')
    ax1.spines[:].set_linewidth(2)
    
    # 绘制位势密度等值线
    salinity_range = np.linspace(34.6, 34.7, 10)
    temperature_range = np.linspace(1, 2.5, 10)
    salinity_grid, temperature_grid = np.meshgrid(salinity_range, temperature_range)
    density_grid = gsw.sigma0(salinity_grid, temperature_grid)

    cs = ax1.contour(salinity_grid, temperature_grid, density_grid, levels=np.arange(27.5, 27.7, 0.01), colors='gray', linewidths=0.5, linestyles='dashed')
    ax1.clabel(cs, fmt='%2.2f', colors='black', fontsize=8)
    
    plt.legend(markerscale=2)
    plt.savefig('salinity_pt_2000.png', bbox_inches='tight', dpi=300)

draw(wen_jian_jia)

# %%
def draw(path_names):
    plt.rcParams['font.size'] = 18
    all_colors = ['#8B8970', '#FFA54F', '#3CB371', '#8B2500', '#E066FF']
    all_markers = ['o', 'D', 'X', '*', '^']
    colors = all_colors[:len(path_names)]
    
    fig = plt.figure(figsize=(10, 10))
    ax1 = fig.add_subplot(111)
    
    for idx, path_name in enumerate(path_names):
        hai_qu_wenjianjia = os.listdir(rf'D:\最新数据\分海区\{path_name}')
        first_file = True
        for i in hai_qu_wenjianjia:
            if i.endswith('.xls'):
                df = pd.read_excel(os.path.join(rf'D:\最新数据\分海区\{path_name}', i), skiprows=3, usecols=[1,5,6,8,10,11,13,16], names=['站位名', '纬度', '经度', '深度', '压力', '水温', '盐度', '溶解氧'])
                df_1 = df[df['深度'] >= 2000]
                depth = df['深度']
                depth_1 = df_1['深度'].values.astype(float)
                o2 = df['溶解氧']
                o2_1 = df_1['溶解氧'].values.astype(float)
                salinity = df['盐度']
                salinity_1 = df_1['盐度'].values.astype(float)
                t = df['水温']
                t_1 = df_1['水温'].values.astype(float)
                p = df['压力'] * 0.1 - 10.1325
                p_1 = df_1['压力'].values * 0.1 - 10.1325
                lon = df['经度'].apply(dms_to_decimal)
                lon_1 = df_1['经度'].apply(dms_to_decimal).values.astype(float)
                lat = df['纬度'].apply(dms_to_decimal)
                lat_1 = df_1['纬度'].apply(dms_to_decimal).values.astype(float)
                
                ab_salinity = gsw.SA_from_SP(salinity_1, p_1, lon_1, lat_1)
                pt = gsw.pt0_from_t(ab_salinity, t_1, p_1)
                
                if first_file:
                    ax1.scatter(salinity_1, o2_1, s=8, marker=all_markers[idx], c=colors[idx], alpha=0.5, label=path_name)
                    first_file = False
                else:
                    ax1.scatter(salinity_1, o2_1, s=8, marker=all_markers[idx], c=colors[idx], alpha=0.5)
        
    # ax1.set_ylim(1, 2.5)
    ax1.set_xlabel('salinity')
    ax1.set_ylabel('o2 (μmol/kg)')
    ax1.spines[:].set_linewidth(2)
    
    # # 绘制位势密度等值线
    # salinity_range = np.linspace(34.6, 34.7, 10)
    # temperature_range = np.linspace(1, 2.5, 10)
    # salinity_grid, temperature_grid = np.meshgrid(salinity_range, temperature_range)
    # density_grid = gsw.sigma0(salinity_grid, temperature_grid)

    # cs = ax1.contour(salinity_grid, temperature_grid, density_grid, levels=np.arange(27.5, 27.7, 0.01), colors='gray', linewidths=0.5, linestyles='dashed')
    # ax1.clabel(cs, fmt='%2.2f', colors='black', fontsize=8)
    
    plt.legend(markerscale=2)
    plt.savefig('salinity_o2.png', bbox_inches='tight', dpi=300)

draw(wen_jian_jia)

# %%
def draw(path_names):
    plt.rcParams['font.size'] = 18
    all_colors = ['#8B8970', '#FFA54F', '#3CB371', '#8B2500', '#E066FF']
    all_markers = ['o', 'D', 'X', '*', '^']
    colors = all_colors[:len(path_names)]
    
    fig = plt.figure(figsize=(10, 10))
    ax1 = fig.add_subplot(111)
    
    for idx, path_name in enumerate(path_names):
        hai_qu_wenjianjia = os.listdir(rf'D:\最新数据\分海区\{path_name}')
        first_file = True
        for i in hai_qu_wenjianjia:
            if i.endswith('.xls'):
                try:
                    df = pd.read_excel(os.path.join(rf'D:\最新数据\分海区\{path_name}', i), skiprows=3, usecols=[1,5,6,8,10,11,13,16], names=['站位名', '纬度', '经度', '深度', '压力', '水温', '盐度', '溶解氧'])
                    df_1 = df[df['深度'] >= 2000]
                    lon_1 = df_1['经度'].apply(dms_to_decimal).values.astype(float)
                    lat_1 = df_1['纬度'].apply(dms_to_decimal).values.astype(float)
                    
                    if first_file:
                        ax1.scatter(lon_1, lat_1, s=8, marker=all_markers[idx], c=colors[idx], alpha=0.5, label=path_name)
                        first_file = False
                    else:
                        ax1.scatter(lon_1, lat_1, s=8, marker=all_markers[idx], c=colors[idx], alpha=0.5)
                except Exception as e:
                    print(f"Error processing file {i}: {e}")
        
    ax1.set_xlabel('Longitude')
    ax1.set_ylabel('Latitude')
    ax1.spines[:].set_linewidth(2)
    
    # plt.legend(markerscale=2)
    # plt.savefig('station_locations.png', bbox_inches='tight', dpi=300)
    plt.show()

draw(wen_jian_jia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 37
#      33     # plt.legend(markerscale=2)
#      34     # plt.savefig('station_locations.png', bbox_inches='tight', dpi=300)
#      35     plt.show()
# ---> 37 draw(wen_jian_jia)
#
# NameError: name 'wen_jian_jia' is not defined
