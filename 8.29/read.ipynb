# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

# %%
ds = xr.open_dataset(r'G:\all_draw\8.29\1_woa23_all_o00_01.nc4', decode_times=False)
ds
# Out:
# <xarray.Dataset> Size: 519kB
# Dimensions:  (time: 1, depth: 102, lat: 31, lon: 41)
# Coordinates:
#   * time     (time) float32 4B 3.894e+03
#   * depth    (depth) float32 408B 0.0 5.0 10.0 15.0 ... 5.3e+03 5.4e+03 5.5e+03
#   * lat      (lat) float32 124B -4.5 -3.5 -2.5 -1.5 -0.5 ... 22.5 23.5 24.5 25.5
#   * lon      (lon) float32 164B 125.5 126.5 127.5 128.5 ... 163.5 164.5 165.5
# Data variables:
#     o_an     (time, depth, lat, lon) float32 519kB ...
#     crs      int32 4B ...
# Attributes: (12/46)
#     Conventions:                     CF-1.6
#     title:                           World Ocean Atlas 2023 : moles_of_oxygen...
#     summary:                         Climatological mean dissolved oxygen for...
#     references:                      Garcia, H.E., Z. Wang, C. Bouchard, S.L....
#     institution:                     NOAA National Centers for Environmental ...
#     comment:                         Global Climatology as part of the World ...
# ...

# %%
ds_1 = xr.open_dataset(r'G:\all_draw\8.29\1_woa23_all_o04_01.nc', decode_times=False)
ds_1
# Out:
# <xarray.Dataset> Size: 290kB
# Dimensions:  (time: 1, depth: 57, lat: 31, lon: 41)
# Coordinates:
#   * time     (time) float32 4B 339.5
#   * depth    (depth) float32 228B 0.0 5.0 10.0 15.0 ... 1.4e+03 1.45e+03 1.5e+03
#   * lat      (lat) float32 124B -4.5 -3.5 -2.5 -1.5 -0.5 ... 22.5 23.5 24.5 25.5
#   * lon      (lon) float32 164B 125.5 126.5 127.5 128.5 ... 163.5 164.5 165.5
# Data variables:
#     o_an     (time, depth, lat, lon) float32 290kB ...
#     crs      int32 4B ...
# Attributes: (12/46)
#     Conventions:                     CF-1.6
#     title:                           World Ocean Atlas 2023 : moles_of_oxygen...
#     summary:                         Climatological mean dissolved oxygen for...
#     references:                      Garcia, H.E., Z. Wang, C. Bouchard, S.L....
#     institution:                     NOAA National Centers for Environmental ...
#     comment:                         Global Climatology as part of the World ...
# ...

# %%
ds_2 = xr.open_dataset(r'G:\all_draw\8.29\1_woa23_all_i04_01.nc', decode_times=False)
ds_2
# Out:
# <xarray.Dataset> Size: 219kB
# Dimensions:  (time: 1, depth: 43, lat: 31, lon: 41)
# Coordinates:
#   * time     (time) float32 4B 339.5
#   * depth    (depth) float32 172B 0.0 5.0 10.0 15.0 ... 650.0 700.0 750.0 800.0
#   * lat      (lat) float32 124B -4.5 -3.5 -2.5 -1.5 -0.5 ... 22.5 23.5 24.5 25.5
#   * lon      (lon) float32 164B 125.5 126.5 127.5 128.5 ... 163.5 164.5 165.5
# Data variables:
#     i_an     (time, depth, lat, lon) float32 219kB ...
#     crs      int32 4B ...
# Attributes: (12/46)
#     Conventions:                     CF-1.6
#     title:                           World Ocean Atlas 2023 : moles_of_silica...
#     summary:
#     references:                      Cross, S.L., H.E. Garcia, C. Bouchard, C...
#     institution:                     NOAA National Centers for Environmental ...
#     comment:                         Global Climatology as part of the World ...
#     ...                              ...
# ...
